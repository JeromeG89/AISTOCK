# %%
Ticker = 'NVDA'
stock = yf.Ticker(Ticker)
earnings = stock.get_earnings_dates()
earnings
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-05-20 16:00:00-04:00           NaN           NaN          NaN
# 2025-02-19 16:00:00-05:00           NaN           NaN          NaN
# 2024-11-19 16:00:00-05:00           NaN           NaN          NaN
# 2024-08-28 16:00:00-04:00          0.64           NaN          NaN
# 2024-05-22 16:00:00-04:00          0.56          0.61       0.0948
# 2024-02-21 16:00:00-05:00          4.64          5.16       0.1132
# 2023-11-21 16:00:00-05:00          3.37          4.02       0.1921
# 2023-08-23 16:00:00-04:00          2.09          2.70       0.2941
# 2023-05-24 16:00:00-04:00          0.92          1.09       0.1857
# 2023-02-22 16:00:00-05:00          0.81          0.88       0.0875
# 2022-11-16 16:00:00-05:00          0.69          0.58      -0.1647
# 2022-08-24 16:00:00-04:00          1.26          0.51      -0.5938

# %%
data_new = yf.Ticker(Ticker).history(period = '31mo', interval ='1wk', auto_adjust = False)
data_old = yf.Ticker(Ticker).history(period = '62mo', interval ='1wk', auto_adjust = False)
def Prep(df, old):
    df.drop('Close', axis = 1, inplace = True)
    df['Dividends'] = df['Dividends']/df['Adj Close']
    df['dir'] = (df['Adj Close'].shift(-3) - df['Adj Close'])
    if old == True:
        df = df.loc[~df.index.isin(data_new.index)]
    df.loc[df['dir'] > 0, 'dir'] = 1
    df.loc[df['dir'] < 0, 'dir'] = 0
    if old == False:
        df['dir'] = df['dir'].fillna('insf')
    return df
df_new = Prep(data_new, old = False).copy()
df_old = Prep(data_old, old = True).copy()
def Cal(df):
    df['std'] = df['Adj Close'].rolling(window = 12, min_periods = 12).std()
    
    dof = np.sign(df['Adj Close'] - df['Adj Close'].shift(1))
    Vol_Change = (df['Volume'] * dof)
    bov = Vol_Change.cumsum()
    df['BOV'] = bov.pct_change()
#Fibonnachi sequence
    Low_60 = df['Adj Close'].rolling(window = 60, min_periods = 60).min()
    High_60 = df['Adj Close'].rolling(window = 60, min_periods = 60).max()
    Dif = High_60 - Low_60
    def Low_cal(k):
        arr = Low_60 + (Dif * k)
        Parr = (df['Adj Close']/arr) -1
        return Parr
    def High_cal(j):
        arr = High_60 - (Dif * j)
        Parr = (df['Adj Close']/arr) -1
        return Parr
    df['SF1'] = Low_cal(0.382)
    df['SF2'] = Low_cal(0.5)
    df['SF3'] = Low_cal(0.618)
    df['SF4'] = Low_cal(0.786)
    df['RC1'] = High_cal(0.786)
    
#Boolinger Bands       
    SMA = df['Adj Close'].rolling(window = 40, min_periods = 40).mean()
    STD = df['Adj Close'].rolling(window = 40, min_periods = 40).std()
    LBol = SMA - (2* STD)
    HBol = SMA + (2* STD)
    df['PLbol'] = ((df['Adj Close'] - LBol) / LBol) 
    df['PHbol'] = ((df['Adj Close'] - HBol) / HBol)
    
#Ichimoku Cloud    
    high_prices = df['High']
    close_prices = df['Adj Close']
    low_prices = df['Low']
    nine_period_high =  df['High'].rolling(window=9).max()
    nine_period_low = df['Low'].rolling(window=9).min()
    tenkan_sen = (nine_period_high + nine_period_low) /2
    period26_high = high_prices.rolling(window=26).max()
    period26_low = low_prices.rolling(window=26).min()
    kijun_sen = (period26_high + period26_low) / 2
    senkou_span_a = ((tenkan_sen + kijun_sen) / 2).shift(26)
    period52_high = high_prices.rolling(window=52).max()
    period52_low = low_prices.rolling(window=52).min()
    senkou_span_b = ((period52_high + period52_low) / 2).shift(26)
    df['kumo'] = senkou_span_a - senkou_span_b
    df['kijun_tenkan'] = tenkan_sen - kijun_sen

#MACD
    ema12 = df['Adj Close'].ewm(span = 13,adjust=False, min_periods = 12).mean()
    ema26 = df['Adj Close'].ewm(span = 26,adjust=False, min_periods = 26).mean()
    MACD = ema12 - ema26
    df['MACD'] = MACD
    ema9 = df['MACD'].ewm(span = 9,adjust=False, min_periods = 9).mean()
    df['ema9'] = ema9
    df['MACD_grad'] = df['MACD'] - df['MACD'].shift(1)
    df['ema9_grad'] = df['ema9'] - df['ema9'].shift(1)
    df['MACD_max'] = df['MACD'].rolling(window = 84).max()
    df['ema9_max'] = df['ema9'].rolling(window = 84).max()
    
#RSI
    cup = df['Adj Close'].diff().copy()
    cdown = df['Adj Close'].diff().copy()
    cup[cup < 0] = 0
    cdown[cdown > 0] = 0
    cup_sum = cup.rolling(14, min_periods = 14).sum()
    cdown_sum = cdown.rolling(14, min_periods = 14).sum() 
    rsi_cal = cup_sum / (cdown_sum * -1)
    RSI = 100 - (100/(1 + rsi_cal))
    df['RSI'] = RSI

#ATR
    def wwma(values, n):
        return values.ewm(alpha=1/n, adjust=False).mean()
    def atr(df, n=14):
        data_work = df.copy()
        high = data_work['High']
        low = data_work['Low']
        close = data_work['Adj Close']
        data_work['tr0'] = abs(high - low)
        data_work['tr1'] = abs(high - close.shift())
        data_work['tr2'] = abs(low - close.shift())
        tr = data_work[['tr0', 'tr1', 'tr2']].max(axis=1)
        atr = wwma(tr, n)
        return atr
    df['atr'] = atr(df, 14)
    
    return df

df_com = pd.concat([Cal(df_old), Cal(df_new)])
df_com.index = df_com.index.strftime('%Y-%m-%d')

# %%
stock = yf.Ticker('NVDA')
print(stock.earnings_dates['EPS Estimate'].dropna()[0])
print(stock.earnings_dates['Reported EPS'].dropna()[0])
print((stock.earnings_dates['Surprise(%)'].dropna() > 0).mean())
# Out:
# 5.51
# 5.16
# 0.75

# %%
luist = []
import yfinance as yf
import pandas as pd
import numpy as np
import time as time
from datetime import datetime
stock_ticks = ['ABBV', 'TJX', 'AMD', 'GE','RSG','KO', 'V', 'PG', 'CL', 'L', 'MMC', 'ROP', 'MCD', 'TMUS', 'WM', 'MA', 'COR', 
                 'YUM', 'PM', 'TJX', 'JNJ', 'KMB', 'HON', 'ITW', 'ATO', 'PEP', 'FI', 'ICE', 'AME', 
                 'LIN', 'KMI', 'WMT', 'JPM', 'LMT', 'MDLZ', 'GD', 'OTIS', 'CHD', 'DUK', 'HIG', 'MO',
                 'CSX', 'AJG', 'WMB', 'STZ', 'CME', 'APH', 'MRK', 'SYY', 'MSI', 'ED', 'AMP', 'ABT', 
                 'VRSK', 'AIG', 'COST', 'VRSN', 'ECL', 'BRO', 'SO', 'PEG', 'LH', 'PPL', 'ABBV', 'CB', 
                 'HOLX', 'BR', 'AVY', 'CTAS', 'IEX', 'MCK', 'KDP', 'TRV', 'DRI', 'CNP', 'ADP', 'FE',
                 'CSCO', 'KHC', 'EA', 'PAYX', 'SRE', 'MDT', 'CMS', 'PRU', 'GIS', 'OKE', 'CBOE', 'LNT',
                 'HD', 'ETR', 'DGX', 'AFL', 'WEC', 'BK', 'JKHY', 'LYB', 'SPGI', 'HLT', 'XYL', 'DOV', 
                 'EXPD', 'VICI', 'PPG', 'ORLY', 'SHW', 'BSX', 'NI', 'LDOS', 'DTE', 'MCO', 'BDX', 'O',
                 'BLK', 'REGN', 'WRB', 'DOW', 'UNP', 'PFG', 'FDS', 'PTC', 'CPRT', 'EVRG', 'TEL', 'CVX', 
                 'HSY', 'AON', 'AVB', 'AAPL', 'FAST', 'INVH', 'MET', 'KR', 'PNW', 'WAB', 'AEP', 'REG', 
                 'TDG', 'VMC', 'K', 'CAG', 'NDSN', 'CTSH', 'IBM', 'SYK', 'AEE', 'PCG', 'FTV', 'XOM',
                 'FFIV', 'EIX', 'EQR', 'GWW', 'WELL', 'ROST', 'MSFT', 'EXC', 'PKG', 'AZO', 'J', 'TMO', 
                 'PCAR', 'NOC', 'ZBH', 'ACN', 'CINF', 'MNST', 'MAR', 'STE', 'LOW', 'AXP', 'CAH', 'HSIC',
                 'RJF', 'LHX', 'BMY', 'GS', 'FRT', 'CDW', 'ELV', 'WTW', 'NWSA', 'C', 'AOS', 'NWS', 'SJM',
                 'TRGP', 'WY', 'GLW', 'IR', 'SNA', 'MLM', 'EMR', 'CMCSA', 'GILD', 'FOX', 'TAP', 'AWK', 
                 'AMCR', 'TSN', 'SPG', 'WFC', 'MAA', 'XEL', 'RTX', 'COP', 'UNH', 'OMC', 'ACGL', 'DHR', 
                 'FOXA', 'CMG', 'BG', 'CMI', 'BKR', 'TSCO', 'TDY', 'HCA', 'AIZ', 'OXY', 'ALL', 'FANG', 
                 'CPB', 'UDR', 'AKAM', 'IRM', 'ESS', 'NDAQ', 'PSA', 'HII', 'ROL', 'TTWO', 'RHI', 'PNR',
                 'CTRA', 'EG', 'ALLE', 'NSC', 'DE', 'VZ', 'EMN', 'BAC', 'VRTX', 'UPS', 'UHS', 'CLX', 
                 'STT', 'TXN', 'T', 'PH', 'EOG', 'CPT', 'COO', 'ETN', 'NVR', 'BIIB', 'HST', 'TYL', 'MS',
                 'TXT', 'MKC', 'FIS', 'PFE', 'GRMN', 'PSX', 'CPAY', 'INCY', 'AMGN', 'TT', 'FDX', 'JCI',
                 'KVUE', 'GPC', 'LKQ', 'COF', 'MAS', 'MOH', 'D', 'CNC', 'AMT', 'EQIX', 'IT', 'GE', 'HES',
                 'CDNS', 'PNC', 'KIM', 'TROW', 'PLD', 'CCI', 'JBHT', 'INTU', 'PGR', 'HUBB', 'VTR', 'SBUX',
                 'DPZ', 'BKNG', 'DVN', 'VTRS', 'ES', 'IPG', 'HWM', 'SLB', 'DD', 'DLR', 'EBAY', 'VLTO', 
                 'ZTS', 'ADSK', 'IQV', 'DIS', 'NKE', 'NRG', 'MPC', 'KEYS', 'ISRG', 'CBRE', 'ADI', 'SNPS',
                 'NUE', 'HAL', 'CE', 'A', 'GPN', 'SYF', 'WRK', 'BAX', 'VLO', 'CAT', 'HBAN', 'APD', 'LYV', 
                 'GOOG', 'TFX', 'AMZN', 'CI', 'HRL', 'GOOGL', 'BEN', 'NTRS', 'MSCI', 'WYNN', 'NEE', 'EW', 
                 'PWR', 'BALL', 'CARR', 'POOL', 'STLD', 'CF', 'DOC', 'HPQ', 'IP', 'CHRW', 'MMM', 'GM', 'DAL', 
                 'LVS', 'MRO', 'IDXX', 'SBAC', 'BBY', 'CSGP', 'JNPR', 'ULTA', 'SCHW', 'TRMB', 'MTB', 'NTAP',
                 'FICO', 'BIO', 'WAT', 'EFX', 'LLY', 'ANSS', 'RL', 'WST', 'LEN', 'NOW', 'ROK', 'GEHC', 'HPE',
                 'QCOM', 'NXPI', 'DLTR', 'PHM', 'CTVA', 'SWK', 'TFC', 'BX', 'BA', 'DHI', 'RF', 'FITB', 'CVS',
                 'USB', 'SWKS', 'RVTY', 'EXR', 'CRL', 'MGM', 'ODFL', 'MTD', 'STX', 'RCL', 'ADBE', 'EQT', 'IVZ',
                 'APA', 'LW', 'BWA', 'KLAC', 'MCHP', 'ORCL', 'AXON', 'TGT', 'GEN', 'HUM', 'MHK', 'QRVO', 'TPR',
                 'AMAT', 'F', 'ADM', 'LRCX', 'MOS', 'HAS', 'IFF', 'ARE', 'VST', 'CRM', 'LULU', 'WDC', 'ABNB', 
                 'FCX', 'TER', 'DAY', 'APTV', 'UBER', 'AVGO', 'CEG', 'CFG', 'NEM', 'CHTR', 'DG', 'TECH', 'NFLX',
                 'DFS', 'DVA', 'PYPL', 'LUV', 'META', 'AES', 'URI', 'MKTX', 'MU', 'MTCH', 'SOLV', 'BBWI', 'KMX',
                 'DECK', 'WBA', 'CMA', 'AAL', 'UAL', 'KEY', 'INTC', 'RMD', 'CTLT', 'ILMN', 'ZBRA', 'DXCM', 'BXP',
                 'FTNT', 'JBL', 'MPWR', 'CZR', 'ANET', 'EL', 'NVDA', 'PODD', 'EXPE', 'ON', 'BLDR', 'FMC', 'ALGN',
                 'CCL', 'AMD', 'ETSY', 'EPAM', 'FSLR', 'PANW', 'GNRC', 'WBD', 'TSLA', 'NCLH', 'ALB', 'PAYC', 'GEV',
                 'MRNA', 'PARA', 'ENPH', 'GL', 'SMCI', 'BRK.B', 'BF.B']

# %%
def ccal(df):
    try:
        yoyIncrease = df['EPS Estimate'].dropna()[0] > df.dropna(subset = ['Reported EPS'])['Reported EPS'][3]
        supriseConsi = ((df['Surprise(%)'].dropna() > 0).mean()) == 1 
        increaseEarnings = (df['EPS Estimate'].dropna()[0] > df['Reported EPS'].dropna()[0])
        conditions = yoyIncrease and supriseConsi and increaseEarnings       
        
        peakEarnings = data['Reported EPS'].dropna()[1:4].max() <= data['EPS Estimate'].dropna()[0]
    except:
        print(f'{ticker}, Failed')
        return 0
    if conditions:
        if peakEarnings:
            return 1, 1
        else:
            return 1, 0
    else:
        return 0, 0

# %%
for ticker in stock_ticks:
    
    try:
        stock = yf.Ticker(ticker)
        data = stock.earnings_dates
        rating = ccal(data)
        if rating == (1, 1):
            luist.append([ticker, data[data['Reported EPS'].isna()].index[-1].date(), True])
        elif rating == (1, 0):
            luist.append([ticker, data[data['Reported EPS'].isna()].index[-1].date(), False])
    except KeyError:
        print(f'{ticker}, Failed')
# Out:
# L, Failed
# SO, Failed
# PEG, Failed
# LH, Failed
# PPL, Failed
# CB, Failed
# HOLX, Failed
# BR, Failed
# AON, Failed
# AVB, Failed
# AAPL, Failed
# FAST, Failed
# INVH, Failed
# MET, Failed
# KR, Failed
# PNW, Failed
# WAB, Failed
# AEP, Failed
# REG, Failed
# TDG, Failed
# NWS, Failed
# FOX, Failed
# TSN, Failed
# SPG, Failed
# WFC, Failed
# MAA, Failed
# XEL, Failed
# RTX, Failed
# COP, Failed
# UNH, Failed
# OMC, Failed
# ACGL, Failed
# DHR, Failed
# CPAY, Failed
# JCI, Failed
# KVUE, Failed
# GPC, Failed
# LKQ, Failed
# COF, Failed
# MAS, Failed
# MOH, Failed
# D, Failed
# CNC, Failed
# AMT, Failed
# EQIX, Failed
# IT, Failed
# DD, Failed
# EW, Failed
# PWR, Failed
# BALL, Failed
# CARR, Failed
# POOL, Failed
# STLD, Failed
# CF, Failed
# DOC, Failed
# HPQ, Failed
# IP, Failed
# CHRW, Failed
# BWA, Failed
# KLAC, Failed
# MCHP, Failed
# ORCL, Failed
# AXON, Failed
# TGT, Failed
# GEN, Failed
# HUM, Failed
# MHK, Failed
# QRVO, Failed
# TPR, Failed
# AMAT, Failed
# DAY, Failed
# SOLV, Failed
# FMC, Failed
# ALGN, Failed
# CCL, Failed
# AMD, Failed
# ETSY, Failed
# EPAM, Failed
# FSLR, Failed
# PANW, Failed
# GNRC, Failed
# WBD, Failed
# TSLA, Failed
# GEV, Failed
# BRK.B: $BRK.B: possibly delisted; No earnings dates found
# BRK.B, Failed
# BF.B: $BF.B: possibly delisted; No earnings dates found
# BF.B, Failed

# %%
data = yf.Ticker('GEV')  
data = data.earnings_dates
ccal(data)
# Out:
# BF.B, Failed
# 0

# %%
output = pd.DataFrame(luist, columns = ['tickers', 'next_earnings', 'Peak']).sort_values(['Peak', 'next_earnings'], ascending = [False, True])
k = [i for i in (output['tickers'])]
k
# Out:
# ['ADBE',
#  'AZO',
#  'CTAS',
#  'PEP',
#  'PG',
#  'ABT',
#  'SLB',
#  'CDNS',
#  'V',
#  'FI',
#  'MSFT',
#  'ROP',
#  'NOW',
#  'RSG',
#  'MA',
#  'LIN',
#  'RCL',
#  'MPWR',
#  'XYL',
#  'ALLE',
#  'ETN',
#  'GPN',
#  'MSCI',
#  'TEL',
#  'BKNG',
#  'CI',
#  'SNPS',
#  'ROST',
#  'LULU',
#  'ADP',
#  'HON',
#  'DECK',
#  'IQV',
#  'QCOM',
#  'MSI',
#  'ED']

# %%
output_path = r'C:\Users\Jerome\Desktop\Jerome_Ground\Stocker_Git\AI_Earning_Scraper\08-10-24.csv'

output.to_csv(output_path, index = False)

# %%
# Out:
# Requirement already satisfied: yfinance in c:\users\jerome\anaconda3\lib\site-packages (0.2.37)
# Collecting yfinance
#   Downloading yfinance-0.2.41-py2.py3-none-any.whl (73 kB)
#                                               0.0/73.5 kB ? eta -:--:--
#      ---------------------------------------- 73.5/73.5 kB ? eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (2.5.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\jerome\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jerome\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\jerome\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jerome\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jerome\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jerome\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jerome\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jerome\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jerome\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.5.7)
# Installing collected packages: yfinance
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.37
#     Uninstalling yfinance-0.2.37:
#       Successfully uninstalled yfinance-0.2.37
# Successfully installed yfinance-0.2.41
# Note: you may need to restart the kernel to use updated packages.

# %%
Ticker = 'PAYC'
stock = yf.Ticker(Ticker)
data = stock.earnings_dates
data
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-02-05 05:00:00-05:00           NaN           NaN          NaN
# 2024-10-29 06:00:00-04:00           NaN           NaN          NaN
# 2024-07-30 06:00:00-04:00           NaN           NaN          NaN
# 2024-04-30 06:00:00-04:00          2.45           NaN          NaN
# 2024-02-07 16:00:00-05:00          1.78          1.93       0.0839
# 2023-10-31 16:00:00-04:00          1.61          1.77       0.1018
# 2023-08-01 16:00:00-04:00          1.59          1.62       0.0162
# 2023-05-02 16:00:00-04:00          2.35          2.46       0.0448
# 2023-02-07 16:00:00-05:00          1.49          1.73       0.1629
# 2022-11-01 16:00:00-04:00          1.18          1.27       0.0742
# 2022-08-02 16:00:00-04:00          1.12          1.26       0.1266
# 2022-05-03 16:00:00-04:00          1.75          1.90       0.0862

# %%
luist2 = []
for i in luist:
    print(i[0])
    luist2.append(i[0])
# Out:
# RE4.SI

# %%
stock = yf.Ticker('RE4.SI')
print(stock.earnings_dates)
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-02-27 20:00:00+08:00           NaN           NaN          NaN
# 2023-11-14 19:00:00+08:00           NaN           NaN          NaN
# 2023-10-31 18:00:00+08:00           NaN           NaN          NaN
# 2023-08-10 18:00:00+08:00           NaN           NaN          NaN
# 2023-05-12 17:00:00+08:00           NaN           NaN          NaN
# 2023-02-27 17:00:00+08:00           NaN           NaN          NaN
# 2022-11-09 18:00:00+08:00           NaN           NaN          NaN
# 2022-08-11 17:00:00+08:00           NaN           NaN          NaN
# 2022-05-12 18:00:00+08:00           NaN           NaN          NaN
# 2022-02-24 17:00:00+08:00           NaN           NaN          NaN
# 2021-11-10 17:00:00+08:00           NaN           NaN          NaN
# 2021-08-11 15:00:00+08:00           NaN           NaN          NaN

# %%
pip install jupyterthemes
# Out:
# Collecting jupyterthemes
#   Downloading jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
#                                               0.0/7.0 MB ? eta -:--:--
#      --                                       0.5/7.0 MB 10.7 MB/s eta 0:00:01
#      ---                                      0.6/7.0 MB 6.4 MB/s eta 0:00:01
#      -------                                  1.3/7.0 MB 9.3 MB/s eta 0:00:01
#      ---------                                1.6/7.0 MB 11.5 MB/s eta 0:00:01
#      ------------                             2.2/7.0 MB 9.8 MB/s eta 0:00:01
#      -----------------                        3.0/7.0 MB 11.2 MB/s eta 0:00:01
#      -----------------------                  4.1/7.0 MB 12.5 MB/s eta 0:00:01
#      ---------------------------              4.8/7.0 MB 12.9 MB/s eta 0:00:01
#      --------------------------------         5.7/7.0 MB 13.4 MB/s eta 0:00:01
#      ------------------------------------     6.4/7.0 MB 13.6 MB/s eta 0:00:01
#      ---------------------------------------  6.9/7.0 MB 13.3 MB/s eta 0:00:01
#      ---------------------------------------- 7.0/7.0 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core in c:\users\jerome\anaconda3\lib\site-packages (from jupyterthemes) (5.3.0)
# Requirement already satisfied: notebook>=5.6.0 in c:\users\jerome\anaconda3\lib\site-packages (from jupyterthemes) (6.5.4)
# Requirement already satisfied: ipython>=5.4.1 in c:\users\jerome\anaconda3\lib\site-packages (from jupyterthemes) (8.12.0)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\jerome\anaconda3\lib\site-packages (from jupyterthemes) (3.7.1)
# Collecting lesscpy>=0.11.2 (from jupyterthemes)
#   Downloading lesscpy-0.15.1-py2.py3-none-any.whl (46 kB)
#                                               0.0/46.7 kB ? eta -:--:--
#      ---------------------------------------- 46.7/46.7 kB ? eta 0:00:00
# Requirement already satisfied: backcall in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: decorator in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (5.7.1)
# Requirement already satisfied: colorama in c:\users\jerome\anaconda3\lib\site-packages (from ipython>=5.4.1->jupyterthemes) (0.4.6)
# Requirement already satisfied: ply in c:\users\jerome\anaconda3\lib\site-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jerome\anaconda3\lib\site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (25.1.0)
# Requirement already satisfied: argon2-cffi in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (8.1.0)
# Requirement already satisfied: ipython-genutils in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: nbformat in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (6.19.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\jerome\anaconda3\lib\site-packages (from notebook>=5.6.0->jupyterthemes) (0.5.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-core->jupyterthemes) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jerome\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\jerome\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\jerome\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: lxml in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.12.2)
# Requirement already satisfied: bleach in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\jerome\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\jerome\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jerome\anaconda3\lib\site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\jerome\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\jerome\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->jupyterthemes) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\jerome\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jerome\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\jerome\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\jerome\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: psutil in c:\users\jerome\anaconda3\lib\site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (5.9.0)
# Requirement already satisfied: executing in c:\users\jerome\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jerome\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\jerome\anaconda3\lib\site-packages (from stack-data->ipython>=5.4.1->jupyterthemes) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jerome\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jerome\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.5.0)
# Requirement already satisfied: jupyter-events>=0.4.0 in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.4.4)
# Requirement already satisfied: websocket-client in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jerome\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jerome\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (2.4)
# Requirement already satisfied: webencodings in c:\users\jerome\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\jerome\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jerome\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\jerome\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\jerome\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.6.0->jupyterthemes) (0.1.1)
# Collecting fqdn (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\jerome\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (2.1)
# Collecting uri-template (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes)
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11 (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes)
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\jerome\anaconda3\lib\site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (1.2.3)
# Installing collected packages: webcolors, uri-template, lesscpy, fqdn, isoduration, jupyterthemes
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 jupyterthemes-0.20.0 lesscpy-0.15.1 uri-template-1.3.0 webcolors-1.13
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t monokai
