# %%
import yfinance as yf
import pandas as pd
import numpy as np

# Define the list of stocks (this is an example; you may expand it to 300 stocks)
stocks = [ 'MSFT', 'AAPL', 'NVDA', 'AMZN', 'META', 'GOOGL', 'GOOG', 'BRK.B', 'LLY', 'AVGO', 
                 'JPM', 'XOM', 'TSLA', 'UNH', 'V', 'PG', 'MA', 'COST', 'JNJ', 'HD', 'MRK', 'NFLX', 
                 'WMT', 'ABBV', 'CVX', 'AMD', 'BAC', 'KO', 'PEP', 'QCOM', 'TMO', 'WFC', 'CRM', 'LIN',
                 'ADBE', 'CSCO', 'ORCL', 'DIS', 'MCD', 'AMAT', 'ACN', 'GE', 'TXN', 'ABT', 'CAT', 'VZ',
                 'DHR', 'AMGN', 'NEE', 'PFE', 'INTU', 'PM', 'CMCSA', 'IBM', 'GS', 'ISRG', 'RTX', 'MU', 
                 'UNP', 'AXP', 'SPGI', 'COP', 'ETN', 'HON', 'NOW', 'UBER', 'BKNG', 'INTC', 'T', 'LRCX', 
                 'LOW', 'MS', 'PGR', 'ELV', 'C', 'TJX', 'SYK', 'VRTX', 'ADI', 'NKE', 'BSX', 'CB', 'MDT',
                 'SCHW', 'BLK', 'KLAC', 'REGN', 'MMC', 'PLD', 'LMT', 'BA', 'ADP', 'UPS', 'CI', 'DE',
                 'PANW', 'MDLZ', 'SBUX', 'AMT', 'TMUS', 'FI', 'BX', 'SNPS', 'CMG', 'SO', 'BMY', 'MO', 
                 'GILD', 'APH', 'CDNS', 'DUK', 'ZTS', 'ANET', 'ICE', 'WM', 'FCX', 'CL', 'TT', 'CME',
                 'MCK', 'TDG', 'CEG', 'EQIX', 'EOG', 'SHW', 'CVS', 'NXPI', 'TGT', 'PH', 'PYPL', 'GD',
                 'HCA', 'BDX', 'CSX', 'SLB', 'ITW', 'MPC', 'ABNB', 'EMR', 'NOC', 'MCO', 'USB', 'PNC',
                 'MSI', 'PSX', 'ECL', 'APD', 'CTAS', 'FDX', 'ORLY', 'WELL', 'MAR', 'ROP', 'AON', 'PCAR', 
                 'AIG', 'MMM', 'AJG', 'EW', 'CARR', 'MCHP', 'COF', 'VLO', 'MRNA', 'GM', 'NSC', 'HLT', 'WMB',
                 'TFC', 'JCI', 'TRV', 'SPG', 'NEM', 'AZO', 'GEV', 'ROST', 'SRE', 'OKE', 'DLR', 'AEP', 
                 'AFL', 'TEL', 'F', 'CPRT', 'DXCM', 'BK', 'URI', 'D', 'FIS', 'KMB', 'MET', 'DHI', 'CCI',
                 'AMP', 'O', 'ALL', 'PRU', 'ADSK', 'HUM', 'PSA', 'SMCI', 'IDXX', 'HES', 'LHX', 'NUE',
                 'IQV', 'PWR', 'OXY', 'GWW', 'STZ', 'DOW', 'OTIS', 'PCG', 'CTVA', 'LEN', 'MSCI', 'AME', 
                 'A', 'PAYX', 'CMI', 'GIS', 'YUM', 'MNST', 'ACGL', 'IR', 'RSG', 'FAST', 'FTNT', 'CNC', 
                 'PEG', 'KMI', 'COR', 'EXC', 'KVUE', 'VRSK', 'SYY', 'MPWR', 'VST', 'FANG', 'KDP', 'MLM',
                 'DD', 'LULU', 'RCL', 'KR', 'VMC', 'XYL', 'GEHC', 'HPQ', 'HWM', 'BKR', 'CTSH', 'IT', 'DAL',
                 'CSGP', 'FICO', 'HAL', 'EA', 'ADM', 'ED', 'BIIB', 'ON', 'ODFL', 'RMD', 'DVN', 'HIG', 'TSCO', 
                 'PPG', 'WAB', 'DFS', 'EXR', 'MTD', 'CDW', 'XEL', 'FSLR', 'ROK', 'VICI', 'HSY', 'EIX', 'EFX', 
                 'EL', 'DG', 'GLW', 'ANSS', 'DECK', 'KHC', 'EBAY', 'CHTR', 'AVB', 'GPN', 'TRGP', 'WTW', 'FTV', 
                 'CBRE', 'TROW', 'CHD', 'DOV', 'TTWO', 'FITB', 'WEC', 'GRMN', 'LYB', 'PHM', 'MTB', 'AWK', 'IFF', 
                 'WST', 'WDC', 'NTAP', 'KEYS', 'DLTR', 'CAH', 'ZBH', 'HPE', 'NVR', 'DTE', 'IRM', 'BR', 'RJF', 
                 'APTV', 'ETR', 'NDAQ', 'STT', 'STE', 'EQR', 'VLTO', 'TER', 'WY', 'BALL', 'PPL', 'CTRA',
                 'HUBB', 'SBAC', 'BRO', 'PTC', 'STLD', 'FE', 'ES', 'TYL', 'AXON', 'LDOS', 'BLDR', 'GPC',
                 'VTR', 'INVH', 'HBAN', 'CPAY', 'NRG', 'ULTA', 'CNP', 'AEE', 'TDY', 'CBOE', 'ALGN', 'CINF',
                 'WAT', 'ARE', 'STX', 'AVY', 'OMC', 'CMS', 'WBD', 'COO', 'ENPH', 'PFG', 'DRI', 'MOH', 'MKC', 
                 'DPZ', 'SYF', 'RF', 'EXPD', 'J', 'NTRS', 'HOLX', 'EQT', 'TXT', 'UAL', 'BAX', 'EG', 'ATO',
                 'MRO', 'ESS', 'LH', 'PKG', 'LVS', 'ZBRA', 'WRB', 'TSN', 'CFG', 'CLX', 'ILMN', 'BBY', 'K',
                 'LUV', 'DGX', 'IEX', 'IP', 'FDS', 'CCL', 'BG', 'JBL', 'CE', 'MAA', 'VRSN', 'MAS', 'CF',
                 'AES', 'ALB', 'EXPE', 'SWKS', 'AMCR', 'SNA', 'CAG', 'GEN', 'TRMB', 'L', 'WRK', 'POOL', 
                 'DOC', 'AKAM', 'RVTY', 'LYV', 'SWK', 'KEY', 'PNR', 'ROL', 'JBHT', 'LNT', 'VTRS', 'HST', 
                 'KIM', 'NDSN', 'LW', 'PODD', 'EVRG', 'TECH', 'EMN', 'IPG', 'JKHY', 'BBWI', 'UDR', 'UHS',
                 'NI', 'LKQ', 'JNPR', 'SJM', 'WBA', 'KMX', 'CPT', 'CRL', 'INCY', 'ALLE', 'MGM', 'NWSA', 
                 'EPAM', 'AOS', 'HII', 'FFIV', 'CHRW', 'REG', 'TAP', 'MOS', 'TFX', 'TPR', 'CTLT', 'QRVO',
                 'GNRC', 'APA', 'HSIC', 'AIZ', 'HRL', 'WYNN', 'PNW', 'CPB', 'FOXA', 'BWA', 'BXP', 'MTCH',
                 'SOLV', 'BF.B', 'DVA', 'PAYC', 'DAY', 'HAS', 'FMC', 'AAL', 'MKTX', 'RL', 'ETSY', 'FRT', 
                 'GL', 'IVZ', 'NCLH', 'RHI', 'CZR', 'CMA', 'BEN', 'MHK', 'BIO', 'PARA', 'FOX', 'NWS'
]


# Define a function to get the historical data and calculate volatility
def get_volatility(ticker):
    data = yf.download(ticker, period="1y")
    data['Returns'] = data['Adj Close'].pct_change()
    volatility = data['Returns'].std() * np.sqrt(252)
    return volatility

# Calculate volatility for each stock
volatility_data = {ticker: get_volatility(ticker) for ticker in stocks}

# Create a DataFrame from the volatility data
volatility_df = pd.DataFrame(list(volatility_data.items()), columns=['Ticker', 'Volatility'])

# Sort the DataFrame by volatility
sorted_volatility_df = volatility_df.sort_values(by='Volatility')

# Get the top 300 low volatility stocks
low_volatility_stocks = sorted_volatility_df['Ticker'].tolist()

print(low_volatility_stocks)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No data found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
len(low_volatility_stocks)
# Out:
# 503

# %%
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 7
#       4 sp500 = yf.download("^GSPC")  # ^GSPC represents the S&P 500 index
#       6 # Get constituents (list of tickers)
# ----> 7 tickers = sp500.constituents.tolist()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'constituents'
